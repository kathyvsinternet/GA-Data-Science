# %% [markdown]
# ## Data Collection
#
# This notebook is set up to collect data from an unofficial IMDb API (theimdbapi.org) as well as the MovieDB API (api.themoviedb.org) based on a list of Hollywood abusers that I have manually collected.
#
# The broad steps are as follows:
# 0. Create CSV of abusers and all of the films they have been involved in with columns:
#     * Name
#     * Role (only looking at "Actor", "Actress", "Director", "Producer", "Writer")
#     * IMDb ID
#     * Title
#     * Type (only "Film" is included)
#     * URL
#     * Year
# 0. Create CSV of all films touched by abusers and main cast and crew with columns:
#     * MovieDB ID
#     * Title
#     * Name
#     * Role (MovieDB API provides more information than IMDb unofficial API)
#     * Gender
# 0. Create CSV of each person and all their projects:
#     * IMDb Person ID
#     * Name
#     * IMDb Movie ID
#     * Title
#     * Type (only "Film" is included)
#     * URL
#     * Year

# %% [markdown]
# ## 1. Abuser Data

# %%
# Set up Python

import pandas as pd
import numpy as np
import csv
import json
import urllib
import requests
import re

# %%
# Import CSV of abusers

abusers = pd.read_csv('../data/hollywood_abusers_list.csv')
abusers.head()

# %%
# Create list of abusers from 'name' column in `abusers`

abuser_names = abusers['name'].tolist()
# debugging: print(abuser_names)

# Create a dictionary of abusers from 'name' and 'imdb_id' in `abusers` when name search in API doesn't work

abuser_ids = abusers.set_index('name')['imdb_id'].to_dict()
# debugging: abuser_ids

# Create a list of roles for this dataset

roles = ['actor', 'actress', 'director', 'producer', 'writer']

# debugging: print(roles)

# %%
# Loop through `abuser_ids` to access unofficial IMDb API and store in dictionary

imdb_person_id = "http://www.theimdbapi.org/api/person?"
imdb_person_name = "http://www.theimdbapi.org/api/find/person?"

abuser_urls = {}
for a in abuser_names:
    result_encoded = imdb_person_name + urllib.parse.urlencode({'name': a})
    result = result_encoded.replace('%2B', '+')
    
    # Create `abuser_urls` dictionary
    
    abuser = a
    urls = result
    abuser_urls[abuser] = urls
    
# debugging: print(abuser_urls)

# %%
# Create dataframe with placeholder data that will be filtered out later

placeholder_abusers = {'imdb_id': 'tt0000000',
               'title': 'test',
               'type': 'test',
               'url': 'http://www.test.com/',
               'year': '2017',
               'name': 'test',
               'role': 'test'}

df_abusers = pd.DataFrame(placeholder_abusers, index = [0])

# debugging: df_abusers

# %% [markdown]
# #### Note: cell below takes a long time to run as it needs to spit out probably 100k rows.

# %%
# Loop through `abuser_urls` dictionary and `roles` list to append API data to `df_abusers`

for abuser, url in abuser_urls.items():
    abuser_json = requests.get(url).json()
    for r in roles:
        try:
            df_abusers_temp = pd.DataFrame(abuser_json[0]['filmography'][r]).assign(name = lambda x: abuser, role = lambda x: r) 
            df_abusers = df_abusers.append(df_abusers_temp, ignore_index = True)
        except KeyError:
            pass

df_abusers.info()

# %%
# Create new dataframe from `df_abusers` where type is "Film" (also deletes test row)

df_abusers_clean = df_abusers[df_abusers.type == 'Film']

# Drop duplicate rows in case there are any

df_abusers_clean.drop_duplicates(['imdb_id', 'name', 'role'], keep = 'first')

# Drop rows where year is NaN as those films are on hold or have not yet been released

df_abusers_clean.dropna(subset=['year'])

# Remove extraneous characters from 'year'

df_abusers_clean['year'] = df_abusers_clean['year'].astype(str).apply(lambda x: x[:4])

# Turn empty columns that aren't NaN into NaN and then drop rows where 'year' is NaN

df_abusers_clean = df_abusers_clean.apply(lambda x: x.str.strip()).replace('', np.nan)
df_abusers_clean = df_abusers_clean[df_abusers_clean.year != 'nan']
df_abusers_clean = df_abusers_clean.dropna(subset = ['year'])

df_abusers_clean.info()

# %%
# Create new CSV from `df_abusers` dataframe

df_abusers_clean.to_csv('../data/abusers_filmography.csv', index = False)

# %% [markdown]
# Step 1 complete!

# %% [markdown]
# ## 2. Film Data

# %%
# Import CSV of abusers' filmography

df_filmography = pd.read_csv('../data/abusers_filmography.csv')
df_filmography.head()

# %%
# Drop all columns except for 'imdb_id'

df_filmography.drop(['name', 'role', 'title', 'type', 'url', 'year'], axis = 1)

# Drop duplicate films

df_filmography.drop_duplicates(keep = 'first', inplace = True)

# %%
# Create list of film IDs from 'imdb_id' column in `df_films`

film_imdb_ids = df_filmography['imdb_id'].tolist()
film_imdb_ids

# %%
# Loop through `film_imdb_ids` to create dictionary for corresponding MovieDB API URLs

moviedb_id = "https://api.themoviedb.org/3/movie/"
moviedb_key = '21acf1b7274aa72fe97cd9acc7eb382a'

film_imdb_moviedb_ids = {}
for f in film_imdb_ids:
    result = moviedb_id + f + "?" + urllib.parse.urlencode({'api_key': moviedb_key}) + "&external_source=imdb_id"
    
    # Create `film_imdb_moviedb_ids` dictionary
    
    imdb = f
    moviedb = result
    film_imdb_moviedb_ids[imdb] = moviedb

film_imdb_moviedb_ids

# %% [markdown]
# #### Cells below strictly for CSV export to create IMDb to MovieDB lookup table

# %%
# Loop through `film_imdb_moviedb_ids` in the MovieDB API to access corresponding MovieDB ID for IMDb ID lookup

film_imdb_moviedb_id_lookup = {}
for i, m in film_imdb_moviedb_ids.items():
    moviedb_json = requests.get(m).json()
    
    # Create `film_moviedb_ids` dictionary
    
    try:
        moviedb_id = moviedb_json['id']
        film_imdb_moviedb_id_lookup[i] = moviedb_id
    except KeyError:
        pass

film_imdb_moviedb_id_lookup

# %%
# Convert `film_imdb_moviedb_id_lookup` dictionary to dataframe

df_film_imdb_moviedb_id_lookup = pd.DataFrame(film_imdb_moviedb_id_lookup, index = [0])
df_film_imdb_moviedb_id_lookup = df_film_imdb_moviedb_id_lookup.transpose().reset_index()
df_film_imdb_moviedb_id_lookup.columns = ['imdb_id', 'moviedb_id']

# Create new CSV

df_film_imdb_moviedb_id_lookup.to_csv('../data/imdb_moviedb_id_lookup.csv', index = False)

# %% [markdown]
# Return to creating dataframes

# %% [markdown]
# #### Note: cell below takes a long time to run.

# %%
# Loop through `film_imdb_moviedb_ids` in the MovieDB API to access corresponding IDs and Title

film_moviedb_ids = {}
for i, m in film_imdb_moviedb_ids.items():
    moviedb_json = requests.get(m).json()
    
    # Create `film_moviedb_ids` dictionary
    
    try:
        ids = moviedb_json['id']
        titles = moviedb_json['title']
        film_moviedb_ids[ids] = titles
    except KeyError:
        pass

# debugging: film_moviedb_ids

# %%
# Create dataframe with placeholder data that will be filtered out later

placeholder_credits = {'moviedb_id': '0000',
                       'title': 'test',
                       'name': 'test',
                       'gender': '0',
                       'role': 'test'}
    
df_credits = pd.DataFrame(placeholder_credits, index = [0])

# debugging: df_credits

# %%
# Loop through `film_moviedb_ids` to pull full credits for each film

for id, title in film_moviedb_ids.items():
    credits_url = moviedb_id + str(id) + "/credits?" + urllib.parse.urlencode({'api_key': moviedb_key})
    credits_json = requests.get(credits_url).json()
    
    # Parse JSON and set to DataFrame
    
    try:
        cast = pd.DataFrame(credits_json['cast']).assign(moviedb_id = lambda x: id,\
                                                         title = lambda x: title, role = lambda x: 'Actor')
        df_credits = df_credits.append(cast, ignore_index = True)
        crew = pd.DataFrame(credits_json['crew']).assign(moviedb_id = lambda x: id,\
                                                         title = lambda x: title)
        crew = crew.rename(columns = {'job': 'role'})
        df_credits = df_credits.append(crew, ignore_index = True)
    except KeyError:
        pass

df_credits.info()

# %%
# Create new dataframe from `df_credits` to only keep rows with relevant credits

df_credits_clean = df_credits[(df_credits.role == 'Actor') | (df_credits.role == 'Director') |\
                             (df_credits.role == 'Executive Producer') | (df_credits.role == 'Producer') |\
                             (df_credits.role == 'Screenplay')]

# Drop extraneous columns

df_credits_clean = df_credits_clean.drop(['cast_id', 'character', 'credit_id',\
                                        'department', 'order', 'profile_path'], axis = 1)

# Rename 'id' to 'person_id'

df_credits_clean = df_credits_clean.rename(columns = {'id': 'person_id'})

# Drop duplicate rows in case there are any

df_credits_clean.drop_duplicates(['moviedb_id', 'person_id', 'role' ], keep = 'first')

# Convert 'person_id' to int64

df_credits_clean['person_id'] = df_credits_clean['person_id'].astype('int64')

# Reorder columns

df_credits_clean = df_credits_clean[['moviedb_id', 'title', 'person_id', 'name', 'role', 'gender']]

df_credits_clean.info()

# %%
# Create new CSV from `df_credits` dataframe

df_credits_clean.to_csv('../data/abusers_film_credits.csv', index = False)

# %% [markdown]
# Step 2 complete!

# %% [markdown]
# ## 3. Person Table

# %%
# Import CSV of film credits

df_person_credits = pd.read_csv('../data/abusers_film_credits.csv')
df_person_credits.head()
# Out:
#    moviedb_id                     title  person_id               name   role  \
# 0       14462  The Manchurian Candidate       5292  Denzel Washington  Actor
# 1       14462  The Manchurian Candidate       5064       Meryl Streep  Actor
# 2       14462  The Manchurian Candidate      23626     Liev Schreiber  Actor
# 3       14462  The Manchurian Candidate      10127         Jon Voight  Actor
# 4       14462  The Manchurian Candidate      55314     Kimberly Elise  Actor
#
#    gender
# 0       2
# 1       1
# 2       2
# 3       2
# 4       1

# %%
# Create new dataframe with all columns except 'person_id' dropped

df_person_id = df_person_credits.drop(['moviedb_id', 'title', 'name', 'role', 'gender'], axis = 1)

# Drop duplicate films

df_person_id.drop_duplicates(keep = 'first', inplace = True)

# Convert 'person_id' column to object so it's iterable

df_person_id['person_id'] = df_person_id['person_id'].astype('object')

# debugging: df_person_id

# %%
# Create list of person IDs from 'person_id' column in `df_person_ids`

person_id = df_person_id['person_id'].tolist()
# debugging: person_id

# %%
# Loop through `person_ids` to create dictionary for corresponding MovieDB API URLs

moviedb_person_id = "https://api.themoviedb.org/3/person/"
moviedb_key = '21acf1b7274aa72fe97cd9acc7eb382a'

person_moviedb_urls = {}
for p in person_id:
    result = moviedb_person_id + str(p) + "?" + urllib.parse.urlencode({'api_key': moviedb_key})
    
    # Create `person_moviedb_urls` dictionary
    
    person_id = p
    moviedb_url = result
    person_moviedb_urls[person_id] = moviedb_url

# debugging: person_moviedb_urls

# %%
person_moviedb_urls
# Out:
# {5292: 'https://api.themoviedb.org/3/person/5292?api_key=21acf1b7274aa72fe97cd9acc7eb382a',
#  5064: 'https://api.themoviedb.org/3/person/5064?api_key=21acf1b7274aa72fe97cd9acc7eb382a',
#  23626: 'https://api.themoviedb.org/3/person/23626?api_key=21acf1b7274aa72fe97cd9acc7eb382a',
#  10127: 'https://api.themoviedb.org/3/person/10127?api_key=21acf1b7274aa72fe97cd9acc7eb382a',
#  55314: 'https://api.themoviedb.org/3/person/55314?api_key=21acf1b7274aa72fe97cd9acc7eb382a',
#  21657: 'https://api.themoviedb.org/3/person/21657?api_key=21acf1b7274aa72fe97cd9acc7eb382a',
#  2954: 'https://api.themoviedb.org/3/person/2954?api_key=21acf1b7274aa72fe97cd9acc7eb382a',
#  16358: 'https://api.themoviedb.org/3/person/16358?api_key=21acf1b7274aa72fe97cd9acc7eb382a',
#  2310: 'https://api.themoviedb.org/3/person/2310?api_key=21acf1b7274aa72fe97cd9acc7eb382a',
#  43366: 'https://api.themoviedb.org/3/person/43366?api_key=21acf1b7274aa72fe97cd9acc7eb382a',
#  15854: 'https://api.themoviedb.org/3/person/15854?api_key=21acf1b7274aa72fe97cd9acc7eb382a',
#  15860: 'https://api.themoviedb.org/3/person/15860?api_key=21acf1b7274aa72fe97cd9acc7eb382a',
#  923: 'https://api.themoviedb.org/3/person/923?api_key=21acf1b7274aa72fe97cd9acc7eb382a',
#  16119: 'https://api.themoviedb.org/3/person/16119?api_key=21acf1b7274aa72fe97cd9acc7eb382a',
#  8693: 'https://api.themoviedb.org/3/person/8693?api_key=21acf1b7274aa72fe97cd9acc7eb382a',
#  1237357: 'https://api.themoviedb.org/3/person/1237357?api_key=21acf1b7274aa72fe97cd9acc7eb382a',
#  59254: 'https://api.themoviedb.org/3/person/59254?api_key=21acf1b7274aa72fe97cd9acc7eb382a',
#  53650: 'https://api.themoviedb.org/3/person/53650?api_key=21acf1b7274aa72fe97cd9acc7eb382a',
#  73913: 'https://api.themoviedb.org/3/person/73913?api_key=21acf1b7274aa72fe97cd9acc7eb382a',
#  52057: 'https://api.themoviedb.org/3/person/52057?api_key=21acf1b7274aa72fe97cd9acc7eb382a',
#  6752: 'https://api.themoviedb.org/3/person/6752?api_key=21acf1b7274aa72fe97cd9acc7eb382a',
#  61607: 'https://api.themoviedb.org/3/person/61607?api_key=21acf1b7274aa72fe97cd9acc7eb382a',
#  20191: 'https://api.themoviedb.org/3/person/20191?api_key=21acf1b7274aa72fe97cd9acc7eb382a',
#  44302: 'https://api.themoviedb.org/3/person/44302?api_key=21acf1b7274aa72fe97cd9acc7eb382a',
#  1520857: 'https://api.themoviedb.org/3/person/1520857?api_key=21acf1b7274aa72fe97cd9acc7eb382a',
#  1534627: 'https://api.themoviedb.org/3/person/1534627?api_key=21acf1b7274aa72fe97cd9acc7eb382a',
#  40103: 'https://api.themoviedb.org/3/person/40103?api_key=21acf1b7274aa72fe97cd9acc7eb382a',
#  1698392: 'https://api.themoviedb.org/3/person/1698392?api_key=21acf1b7274aa72fe97cd9acc7eb382a',
#  164094: 'https://api.themoviedb.org/3/person/164094?api_key=21acf1b7274aa72fe97cd9acc7eb382a',
#  16294: 'https://api.themoviedb.org/3/person/16294?api_key=21acf1b7274aa72fe97cd9acc7eb382a',
#  29378: 'https://api.themoviedb.org/3/person/29378?api_key=21acf1b7274aa72fe97cd9acc7eb382a',
#  20516: 'https://api.themoviedb.org/3/person/20516?api_key=21acf1b7274aa72fe97cd9acc7eb382a',
#  17751: 'https://api.themoviedb.org/3/person/17751?api_key=21acf1b7274aa72fe97cd9acc7eb382a',
#  27095: 'https://api.themoviedb.org/3/person/27095?api_key=21acf1b7274aa72fe97cd9acc7eb382a',
#  2997: 'https://api.themoviedb.org/3/person/2997?api_key=21acf1b7274aa72fe97cd9acc7eb382a',
#  1470041: 'https://api.themoviedb.org/3/person/1470041?api_key=21acf1b7274aa72fe97cd9acc7eb382a',
#  31: 'https://api.themoviedb.org/3/person/31?api_key=21acf1b7274aa72fe97cd9acc7eb382a',
#  12538: 'https://api.themoviedb.org/3/person/12538?api_key=21acf1b7274aa72fe97cd9acc7eb382a',
#  65019: 'https://api.themoviedb.org/3/person/65019?api_key=21acf1b7274aa72fe97cd9acc7eb382a',
#  7219: 'https://api.themoviedb.org/3/person/7219?api_key=21acf1b7274aa72fe97cd9acc7eb382a',
#  22111: 'https://api.themoviedb.org/3/person/22111?api_key=21acf1b7274aa72fe97cd9acc7eb382a',
#  17401: 'https://api.themoviedb.org/3/person/17401?api_key=21acf1b7274aa72fe97cd9acc7eb382a',
#  1279102: 'https://api.themoviedb.org/3/person/1279102?api_key=21acf1b7274aa72fe97cd9acc7eb382a',
#  68122: 'https://api.themoviedb.org/3/person/68122?api_key=21acf1b7274aa72fe97cd9acc7eb382a',
#  156999: 'https://api.themoviedb.org/3/person/156999?api_key=21acf1b7274aa72fe97cd9acc7eb382a',
#  119521: 'https://api.themoviedb.org/3/person/119521?api_key=21acf1b7274aa72fe97cd9acc7eb382a',
#  16841: 'https://api.themoviedb.org/3/person/16841?api_key=21acf1b7274aa72fe97cd9acc7eb382a',
#  2130: 'https://api.themoviedb.org/3/person/2130?api_key=21acf1b7274aa72fe97cd9acc7eb382a',
#  161856: 'https://api.themoviedb.org/3/person/161856?api_key=21acf1b7274aa72fe97cd9acc7eb382a',
#  43222: 'https://api.themoviedb.org/3/person/43222?api_key=21acf1b7274aa72fe97cd9acc7eb382a',
#  
api_key=21acf1b7274aa72fe97cd9acc7eb382a',
#  49906: 'https://api.themoviedb.org/3/person/49906?api_key=21acf1b7274aa72fe97cd9acc7eb382a',
#  161738: 'https://api.themoviedb.org/3/person/161738?api_key=21acf1b7274aa72fe97cd9acc7eb382a',
#  121038: 'https://api.themoviedb.org/3/person/121038?api_key=21acf1b7274aa72fe97cd9acc7eb382a',
#  93622: 'https://api.themoviedb.org/3/person/93622?api_key=21acf1b7274aa72fe97cd9acc7eb382a',
#  184636: 'https://api.themoviedb.org/3/person/184636?api_key=21acf1b7274aa72fe97cd9acc7eb382a',
#  130373: 'https://api.themoviedb.org/3/person/130373?api_key=21acf1b7274aa72fe97cd9acc7eb382a',
#  176534: 'https://api.themoviedb.org/3/person/176534?api_key=21acf1b7274aa72fe97cd9acc7eb382a',
#  861: 'https://api.themoviedb.org/3/person/861?api_key=21acf1b7274aa72fe97cd9acc7eb382a',
#  106504: 'https://api.themoviedb.org/3/person/106504?api_key=21acf1b7274aa72fe97cd9acc7eb382a',
#  70985: 'https://api.themoviedb.org/3/person/70985?api_key=21acf1b7274aa72fe97cd9acc7eb382a',
#  12151: 'https://api.themoviedb.org/3/person/12151?api_key=21acf1b7274aa72fe97cd9acc7eb382a',
#  10606: 'https://api.themoviedb.org/3/person/10606?api_key=21acf1b7274aa72fe97cd9acc7eb382a',
#  9857: 'https://api.themoviedb.org/3/person/9857?api_key=21acf1b7274aa72fe97cd9acc7eb382a',
#  38244: 'https://api.themoviedb.org/3/person/38244?api_key=21acf1b7274aa72fe97cd9acc7eb382a',
#  32923: 'https://api.themoviedb.org/3/person/32923?api_key=21acf1b7274aa72fe97cd9acc7eb382a',
#  105789: 'https://api.themoviedb.org/3/person/105789?api_key=21acf1b7274aa72fe97cd9acc7eb382a',
#  105790: 'https://api.themoviedb.org/3/person/105790?api_key=21acf1b7274aa72fe97cd9acc7eb382a',
#  1613750: 'https://api.themoviedb.org/3/person/1613750?api_key=21acf1b7274aa72fe97cd9acc7eb382a',
#  1184839: 'https://api.themoviedb.org/3/person/1184839?api_key=21acf1b7274aa72fe97cd9acc7eb382a',
#  106102: 'https://api.themoviedb.org/3/person/106102?api_key=21acf1b7274aa72fe97cd9acc7eb382a',
#  38528: 'https://api.themoviedb.org/3/person/38528?api_key=21acf1b7274aa72fe97cd9acc7eb382a',
#  82189: 'https://api.themoviedb.org/3/person/82189?api_key=21acf1b7274aa72fe97cd9acc7eb382a',
#  17666: 'https://api.themoviedb.org/3/person/17666?api_key=21acf1b7274aa72fe97cd9acc7eb382a',
#  12497: 'https://api.themoviedb.org/3/person/12497?api_key=21acf1b7274aa72fe97cd9acc7eb382a',
#  12499: 'https://api.themoviedb.org/3/person/12499?api_key=21acf1b7274aa72fe97cd9acc7eb382a',
#  12498: 'https://api.themoviedb.org/3/person/12498?api_key=21acf1b7274aa72fe97cd9acc7eb382a',
#  12500: 'https://api.themoviedb.org/3/person/12500?api_key=21acf1b7274aa72fe97cd9acc7eb382a',
#  12505: 'https://api.themoviedb.org/3/person/12505?api_key=21acf1b7274aa72fe97cd9acc7eb382a',
#  12501: 'https://api.themoviedb.org/3/person/12501?api_key=21acf1b7274aa72fe97cd9acc7eb382a',
#  12502: 'https://api.themoviedb.org/3/person/12502?api_key=21acf1b7274aa72fe97cd9acc7eb382a',
#  12504: 'https://api.themoviedb.org/3/person/12504?api_key=21acf1b7274aa72fe97cd9acc7eb382a',
#  5792: 'https://api.themoviedb.org/3/person/5792?api_key=21acf1b7274aa72fe97cd9acc7eb382a',
#  ...}

# %% [markdown]
# #### Note: cell below takes a long time to run as it runs through API and spits out more than 10k rows.

# %%
# Loop through `person_moviedb_urls` in the MovieDB API to access corresponding IMDB IDs

person_imdb_ids = {}
for i, url in person_moviedb_urls.items():
    person_json = requests.get(url).json()
    
    # Create `person_imdb_ids`dictionary
    
    try:
        imdb_id = person_json['imdb_id']
    except KeyError:
        pass
    moviedb_id = i
    person_imdb_ids[moviedb_id] = imdb_id

# debugging: person_imdb_ids
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-41-433b4a694785> in <module>()
#       3 person_imdb_ids = {}
#       4 for i, url in person_moviedb_urls.items():
# ----> 5     person_json = requests.get(url).json()
#       6
#       7     # Create `person_imdb_ids`dictionary
#
# /Users/206886/anaconda/lib/python3.6/site-packages/requests/api.py in get(url, params, **kwargs)
#      70
#      71     kwargs.setdefault('allow_redirects', True)
# ---> 72     return request('get', url, params=params, **kwargs)
#      73
#      74
#
# /Users/206886/anaconda/lib/python3.6/site-packages/requests/api.py in request(method, url, **kwargs)
#      56     # cases, and look like a memory leak in others.
#      57     with sessions.Session() as session:
# ---> 58         return session.request(method=method, url=url, **kwargs)
#      59
#      60
#
# /Users/206886/anaconda/lib/python3.6/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     516         }
#     517         send_kwargs.update(settings)
# --> 518         resp = self.send(prep, **send_kwargs)
#     519
#     520         return resp
#
# /Users/206886/anaconda/lib/python3.6/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     637
#     638         # Send the request
# --> 639         r = adapter.send(request, **kwargs)
#     640
#     641         # Total elapsed time of the request (approximately)
#
# /Users/206886/anaconda/lib/python3.6/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     436                     decode_content=False,
#     437                     retries=self.max_retries,
# --> 438                     timeout=timeout
#     439                 )
#     440
#
# /Users/206886/anaconda/lib/python3.6/site-packages/requests/packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     598                                                   timeout=timeout_obj,
#     599                                                   body=body, headers=headers,
# --> 600                                                   chunked=chunked)
#     601
#     602             # If we're going to release the connection in ``finally:``, then
#
# /Users/206886/anaconda/lib/python3.6/site-packages/requests/packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     343         # Trigger any extra validation we need to do.
#     344         try:
# --> 345             self._validate_conn(conn)
#     346         except (SocketTimeout, BaseSSLError) as e:
#     347             # Py2 raises this as a BaseSSLError, Py3 raises it as socket timeout.
#
# /Users/206886/anaconda/lib/python3.6/site-packages/requests/packages/urllib3/connectionpool.py in _validate_conn(self, conn)
#     842         # Force connect early to allow us to validate the connection.
#     843         if not getattr(conn, 'sock', None):  # AppEngine might not have  `.sock`
# --> 844             conn.connect()
#     845
#     846         if not conn.is_verified:
#
# /Users/206886/anaconda/lib/python3.6/site-packages/requests/packages/urllib3/connection.py in connect(self)
#     324             ca_cert_dir=self.ca_cert_dir,
#     325             server_hostname=hostname,
# --> 326             ssl_context=context)
#     327
#     328         if self.assert_fingerprint:
#
# /Users/206886/anaconda/lib/python3.6/site-packages/requests/packages/urllib3/util/ssl_.py in ssl_wrap_socket(sock, keyfile, certfile, cert_reqs, ca_certs, server_hostname, ssl_version, ciphers, ssl_context, ca_cert_dir)
#     307     if ca_certs or ca_cert_dir:
#     308         try:
# --> 309             context.load_verify_locations(ca_certs, ca_cert_dir)
#     310         except IOError as e:  # Platform-specific: Python 2.6, 2.7, 3.2
#     311             raise SSLError(e)
#
# /Users/206886/anaconda/lib/python3.6/site-packages/requests/packages/urllib3/contrib/pyopenssl.py in load_verify_locations(self, cafile, capath, cadata)
#     411         if capath is not None:
#     412             capath = capath.encode('utf-8')
# --> 413         self._ctx.load_verify_locations(cafile, capath)
#     414         if cadata is not None:
#     415             self._ctx.load_verify_locations(BytesIO(cadata))
#
# /Users/206886/anaconda/lib/python3.6/site-packages/OpenSSL/SSL.py in load_verify_locations(self, cafile, capath)
#     664
#     665         load_result = _lib.SSL_CTX_load_verify_locations(
# --> 666             self._context, cafile, capath
#     667         )
#     668         if not load_result:
#
# KeyboardInterrupt:

# %%
# Convert `person_imdb_ids` dictionary to dataframe

df_person_imdb_ids = pd.DataFrame(person_imdb_ids, index = [0])
df_person_imdb_ids_clean = df_person_imdb_ids.transpose().reset_index()
df_person_imdb_ids_clean.columns = ["moviedb_id", "imdb_id"]

# Create new CSV

df_person_imdb_ids_clean.to_csv('../data/person_api_imdb_id.csv', index = False)

# %% [markdown]
# #### Note to self: if kernel needs to be restarted, start here for step 3.

# %%
# Import `person_api_imdb_id.csv` as kernel restarts

df_person_api_imdb_id = pd.read_csv('../data/person_api_imdb_id.csv')

# Drop rows where 'imdb_id' is NaN

df_person_api_imdb_id = df_person_api_imdb_id.dropna(subset=['imdb_id'])

df_person_api_imdb_id.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 11588 entries, 0 to 13859
# Data columns (total 2 columns):
# moviedb_url    11588 non-null object
# imdb_id        11588 non-null object
# dtypes: object(2)
# memory usage: 271.6+ KB

# %%
# Create list of 'imdb_id' from `person_imdb_ids` dataframe

person_imdb_ids = df_person_api_imdb_id['imdb_id'].tolist()
# debugging: person_imdb_ids

# %%
# Loop through `person_imdb_ids` to access unofficial IMDb API and store in dictionary

imdb_person_id = "http://www.theimdbapi.org/api/person?"

imdb_person_url = {}
for i in person_imdb_ids:
    urls = imdb_person_id + urllib.parse.urlencode({'person_id': i})
    
    # Create `imdb_person_url` dictionary
    
    imdb_person_url[i] = urls
    
# debugging: imdb_person_url

# %%
# Create dataframe with placeholder data that will be filtered out later

placeholder_person = {'person_id': 'nm0000000',
                      'name': 'test',
                      'imdb_id': 'tt0000000',
                      'title': 'test', 
                      'type': 'test',
                      'url': 'http://www.test.com/',
                      'year': '2017',
                      'name': 'test',
                      'role': 'test'}
    
df_person_filmography = pd.DataFrame(placeholder_person, index = [0])
# debugging: df_person_filmography

# %%
# Repeat list of rows

roles = ['actor', 'actress', 'director', 'producer', 'writer']

# %% [markdown]
# #### Note to self: next cell takes forever to run as it needs to loop through API pages to pull the filmography data for 30-50k people who have worked with known abusers. End result is hundreds of thousands of rows large if not over one million. Run sparingly.

# %%
# Loop through `df_person_filmography` and `roles` list to append API data to `df_person_filmography`

for i, url in imdb_person_url.items():
    person_filmography_json = [requests.get(url).json()]
    #print(person_filmography_json)
    for r in roles:
        try:
            df_person_temp = pd.DataFrame(person_filmography_json[0]['filmography'][r]).assign(name = lambda x: person_filmography_json[0]['title'], person_id = lambda x: person_filmography_json[0]['person_id'], role = lambda x: r)
            df_person_filmography = df_person_filmography.append(df_person_temp, ignore_index = True)
        except KeyError:
            pass
        except TypeError:
            pass
        except JSONDecodeError:
            pass

df_person_filmography.info()
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-22-bf0e0b01359c> in <module>()
#       2
#       3 for i, url in imdb_person_url.items():
# ----> 4     person_filmography_json = [requests.get(url).json()]
#       5     #print(person_filmography_json)
#       6     for r in roles:
#
# /Users/206886/anaconda/lib/python3.6/site-packages/requests/models.py in json(self, **kwargs)
#     883                     # used.
#     884                     pass
# --> 885         return complexjson.loads(self.text, **kwargs)
#     886
#     887     @property
#
# /Users/206886/anaconda/lib/python3.6/json/__init__.py in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     352             parse_int is None and parse_float is None and
#     353             parse_constant is None and object_pairs_hook is None and not kw):
# --> 354         return _default_decoder.decode(s)
#     355     if cls is None:
#     356         cls = JSONDecoder
#
# /Users/206886/anaconda/lib/python3.6/json/decoder.py in decode(self, s, _w)
#     337
#     338         """
# --> 339         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     340         end = _w(s, end).end()
#     341         if end != len(s):
#
# /Users/206886/anaconda/lib/python3.6/json/decoder.py in raw_decode(self, s, idx)
#     355             obj, end = self.scan_once(s, idx)
#     356         except StopIteration as err:
# --> 357             raise JSONDecodeError("Expecting value", s, err.value) from None
#     358         return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)

# %% [markdown]
# #### NOTE: CELL ABOVE TAKES FOREVER AND KEEPS BREAKING
#
# Despite the JSONDecodeError exception, code breaks with "JSONDecodeError: Expecting value: line 1 column 1 (char 0)" and dataframe ends around 100k and only loops through 2-3k people.
#
# #### Need to fix for final deliverable

# %%
df_person_filmography.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100260 entries, 0 to 100259
# Data columns (total 8 columns):
# imdb_id      100260 non-null object
# name         100260 non-null object
# person_id    100260 non-null object
# role         100260 non-null object
# title        100260 non-null object
# type         100260 non-null object
# url          100260 non-null object
# year         100260 non-null object
# dtypes: object(8)
# memory usage: 6.1+ MB

# %%
df_person_filmography.head()
# Out:
#      imdb_id            name  person_id     role                 title  type  \
# 0  tt0000000            test  nm0000000     test                  test  test
# 1  tt0017419  Carol Dempster  nm0218781  actress  The Sorrows of Satan  Film
# 2  tt0016420  Carol Dempster  nm0218781  actress       That Royle Girl  Film
# 3  tt0016308  Carol Dempster  nm0218781  actress  Sally of the Sawdust  Film
# 4  tt0015018  Carol Dempster  nm0218781  actress  Isn't Life Wonderful  Film
#
#                                     url  year
# 0                  http://www.test.com/  2017
# 1  http://www.imdb.com/title/tt0017419/  1926
# 2  http://www.imdb.com/title/tt0016420/  1925
# 3  http://www.imdb.com/title/tt0016308/  1925
# 4  http://www.imdb.com/title/tt0015018/  1924

# %%
# Create new dataframe from `df_person_filmography` where type is "Film" (also deletes test row)

df_person_filmography_clean = df_person_filmography[df_person_filmography.type == 'Film']

# Drop duplicate rows in case there are any

df_person_filmography_clean.drop_duplicates(['imdb_id', 'name', 'person_id', 'role'], keep = 'first')

# Drop rows where year is NaN as those films are on hold or have not yet been released

df_person_filmography_clean.dropna(subset=['year'])

# Remove extraneous characters from 'year'

df_person_filmography_clean['year'] = df_person_filmography_clean['year'].astype(str).apply(lambda x: x[:4])

# Turn empty columns that aren't NaN into NaN and then drop rows where 'year' is NaN

df_person_filmography_clean = df_person_filmography_clean.apply(lambda x: x.str.strip()).replace('', np.nan)
df_person_filmography_clean = df_person_filmography_clean[df_person_filmography_clean.year != 'nan']
df_person_filmography_clean = df_person_filmography_clean.dropna(subset = ['year'])

df_person_filmography_clean.info()
# Out:
# /Users/206886/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 57889 entries, 1 to 100253
# Data columns (total 8 columns):
# imdb_id      57889 non-null object
# name         57889 non-null object
# person_id    57889 non-null object
# role         57889 non-null object
# title        57889 non-null object
# type         57889 non-null object
# url          57889 non-null object
# year         57889 non-null object
# dtypes: object(8)
# memory usage: 4.0+ MB

# %%
# Create new CSV from `df_person_filmography_clean` dataframe

df_person_filmography_clean.to_csv('../data/person_filmography.csv', index = False)

# %% [markdown]
# Step 3 complete!

# %% [markdown]
# ## Ingore everything below

# %%
# EXAMPLE HERE TO DELETE

for i, u in test5.items():
    test_json = [requests.get(u).json()]
    #print(test_json)
    #name = test_json[0]['title']
    #person_id = test_json[0]['person_id']
    for r in roles:
        try:
            df_temp = pd.DataFrame(test_json[0]['filmography'][r]).assign(name = lambda x: test_json[0]['title'] , person_id = lambda x: test_json[0]['person_id'], role = lambda x: r) 
            test9 = test9.append(df_temp, ignore_index = True)
        except KeyError:
            pass
test9

# %%
# TEST

test3 = {53930: 'https://api.themoviedb.org/3/person/53930?api_key=21acf1b7274aa72fe97cd9acc7eb382a',
         42003: 'https://api.themoviedb.org/3/person/42003?api_key=21acf1b7274aa72fe97cd9acc7eb382a',
         62547: 'https://api.themoviedb.org/3/person/62547?api_key=21acf1b7274aa72fe97cd9acc7eb382a', 
         109: 'https://api.themoviedb.org/3/person/109?api_key=21acf1b7274aa72fe97cd9acc7eb382a' }

test4 = {}
for i, u in test3.items():
    test_json = requests.get(u).json()
    
    # dictionary
    
    imdb_id = test_json['imdb_id']
    test4[u] = imdb_id

test4
# Out:
# {'https://api.themoviedb.org/3/person/109?api_key=21acf1b7274aa72fe97cd9acc7eb382a': 'nm0000704',
#  'https://api.themoviedb.org/3/person/42003?api_key=21acf1b7274aa72fe97cd9acc7eb382a': 'nm0834373',
#  'https://api.themoviedb.org/3/person/53930?api_key=21acf1b7274aa72fe97cd9acc7eb382a': 'nm0001499',
#  'https://api.themoviedb.org/3/person/62547?api_key=21acf1b7274aa72fe97cd9acc7eb382a': 'nm0860749'}

# %%
# TEST

imdb_person_id = "http://www.theimdbapi.org/api/person?"

test5 = {}
for u, t in test4.items():
    urls = imdb_person_id + urllib.parse.urlencode({'person_id': t})
    
    # dictionary
    
    test5[t] = urls
    
test5
# Out:
# {'nm0000704': 'http://www.theimdbapi.org/api/person?person_id=nm0000704',
#  'nm0001499': 'http://www.theimdbapi.org/api/person?person_id=nm0001499',
#  'nm0834373': 'http://www.theimdbapi.org/api/person?person_id=nm0834373',
#  'nm0860749': 'http://www.theimdbapi.org/api/person?person_id=nm0860749'}

# %%
# TEST

test6 = {'imdb_id': 'nm0000000',
         'name': 'test',
         'actor': 'test', 
         'director': 'test', 
         'producer': 'test', 
         'writer': 'test'}
    
test7 = pd.DataFrame(test6, index = [0])

test7

test8 = {'imdb_id': 'tt0000000',
         'title': 'test',
         'type': 'test',
         'url': 'http://www.test.com/',
         'year': '2017',
         'name': 'test',
         'role': 'test'}

test9 = pd.DataFrame(test8, index = [0])

test9
# Out:
#      imdb_id  name  role title  type                   url  year
# 0  tt0000000  test  test  test  test  http://www.test.com/  2017

# %%
# TEST

# Repeat list of rows

roles = ['actor', 'actress', 'director', 'producer', 'writer']

for i, u in test5.items():
    test_json = [requests.get(u).json()]
    #print(test_json)
    #name = test_json[0]['title']
    #person_id = test_json[0]['person_id']
    for r in roles:
        try:
            df_temp = pd.DataFrame(test_json[0]['filmography'][r]).assign(name = lambda x: test_json[0]['title'] , person_id = lambda x: test_json[0]['person_id'], role = lambda x: r) 
            test9 = test9.append(df_temp, ignore_index = True)
        except KeyError:
            pass
test9
# Out:
#        imdb_id           name  person_id      role  \
# 0    tt0000000           test        NaN      test
# 1    tt3514324  Tina Majorino  nm0001499   actress
# 2    tt4265778  Tina Majorino  nm0001499   actress
# 3    tt2402137  Tina Majorino  nm0001499   actress
# 4    tt2771372  Tina Majorino  nm0001499   actress
# 13   http://www.imdb.com/title/tt1825909/       2011
# 14   http://www.imdb.com/title/tt1600200/       2010
# 15   http://www.imdb.com/title/tt1441219/       2010
# 16   http://www.imdb.com/title/tt0384683/       2007
# 17   http://www.imdb.com/title/tt0412253/  2004-2007
# 18   http://www.imdb.com/title/tt0497493/       2006
# 19   http://www.imdb.com/title/tt0403598/       2006
# 20   http://www.imdb.com/title/tt0780624/       2005
# 21   http://www.imdb.com/title/tt0321021/       2004
# 22   http://www.imdb.com/title/tt0374900/       2004
# 23   http://www.imdb.com/title/tt0164993/       1999
# 24   http://www.imdb.com/title/tt0136399/       1997
# 25   http://www.imdb.com/title/tt0128072/       1997
# 26   http://www.imdb.com/title/tt0120062/       1997
# 27   http://www.imdb.com/title/tt0118499/       1997
# 28   http://www.imdb.com/title/tt0117170/       1996
# 29   http://www.imdb.com/title/tt0114898/       1995
# ..                                    ...        ...
# 265  http://www.imdb.com/title/tt0116322/       1996
# 266  http://www.imdb.com/title/tt0111667/       1994
# 267  http://www.imdb.com/title/tt0110687/       1994
# 268  http://www.imdb.com/title/tt0106004/       1994
# 269  http://www.imdb.com/title/tt0107034/       1993
# 270  http://www.imdb.com/title/tt0106223/       1993
# 271  http://www.imdb.com/title/tt0105830/       1993
# 272  http://www.imdb.com/title/tt0104291/       1992
# 273  http://www.imdb.com/title/tt0104059/       1992
# 274  http://www.imdb.com/title/tt0105211/       1992
# 275  http://www.imdb.com/title/tt0102631/       1991
# 276  http://www.imdb.com/title/tt0099073/       1990
# 277  http://www.imdb.com/title/tt0099252/       1990
# 278  http://www.imdb.com/title/tt0099850/       1990
# 279  http://www.imdb.com/title/tt0096874/       1989
# 280  http://www.imdb.com/title/tt6998518/     2018/I
# 281  http://www.imdb.com/title/tt4270452/       2018
# 282  http://www.imdb.com/title/tt7014102/       2018
# 283  http://www.imdb.com/title/tt2473110/
# 284  http://www.imdb.com/title/tt1837687/
# 285  http://www.imdb.com/title/tt6069264/     2017/I
# 286  http://www.imdb.com/title/tt4381236/       2016
# 287  http://www.imdb.com/title/tt3349380/       2015
# 288  http://www.imdb.com/title/tt2443822/     2015/I
# 289  http://www.imdb.com/title/tt3455740/       2014
# 290  http://www.imdb.com/title/tt2409818/       2014
# 291  http://www.imdb.com/title/tt2326554/       2014
# 292  http://www.imdb.com/title/tt2490326/       2014
# 293  http://www.imdb.com/title/tt2660332/       2013
# 294  http://www.imdb.com/title/tt2076372/       2012
#
# [295 rows x 8 columns]

# %%
test9.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 295 entries, 0 to 294
# Data columns (total 8 columns):
# imdb_id      295 non-null object
# name         295 non-null object
# person_id    294 non-null object
# role         295 non-null object
# title        295 non-null object
# type         295 non-null object
# url          295 non-null object
# year         295 non-null object
# dtypes: object(8)
# memory usage: 18.5+ KB

# %%
test9['role'].value_counts()
# Out:
# actress     181
# actor        98
# producer     15
# test          1
# Name: role, dtype: int64

# %%
test9['name'].value_counts()
# Out:
# Elijah Wood        113
# Gail Strickland     94
# Susanna Thompso     53
# Tina Majorino       34
# test                 1
# Name: name, dtype: int64

# %%
# 30   http://www.imdb.com/title/tt0109120/    1994
# 31   http://www.imdb.com/title/tt0109484/    1994
# 32   http://www.imdb.com/title/tt0111693/    1994
# 35   http://www.imdb.com/title/tt0119970/  2008/I
# 41   http://www.imdb.com/title/tt0160468/    1998
# 48   http://www.imdb.com/title/tt0112346/    1995
# 49   http://www.imdb.com/title/tt0113347/    1995
# 50   http://www.imdb.com/title/tt0113860/    1995
# 52   http://www.imdb.com/title/tt0110312/    1994
# 54   http://www.imdb.com/title/tt0111693/    1994
# 56   http://www.imdb.com/title/tt0106355/    1993
# 58   http://www.imdb.com/title/tt0108334/    1993
# 59   http://www.imdb.com/title/tt0108134/    1993
# 61   http://www.imdb.com/title/tt0255612/    1992
# 62   http://www.imdb.com/title/tt0103897/    1992
# 64   http://www.imdb.com/title/tt0102388/    1991
# ..                                    ...     ...
# 258  http://www.imdb.com/title/tt0128977/    1999
# 259  http://www.imdb.com/title/tt0133751/    1998
# 260  http://www.imdb.com/title/tt0120647/    1998
# 262  http://www.imdb.com/title/tt0119349/    1997
# 265  http://www.imdb.com/title/tt0116322/    1996
# 266  http://www.imdb.com/title/tt0111667/    1994
# 267  http://www.imdb.com/title/tt0110687/    1994
# 269  http://www.imdb.com/title/tt0107034/    1993
# 270  http://www.imdb.com/title/tt0106223/    1993
# 272  http://www.imdb.com/title/tt0104291/    1992
# 273  http://www.imdb.com/title/tt0104059/    1992
# 274  http://www.imdb.com/title/tt0105211/    1992
# 275  http://www.imdb.com/title/tt0102631/    1991
# 276  http://www.imdb.com/title/tt0099073/    1990
# 277  http://www.imdb.com/title/tt0099252/    1990
# 278  http://www.imdb.com/title/tt0099850/    1990
# 280  http://www.imdb.com/title/tt6998518/  2018/I
# 281  http://www.imdb.com/title/tt4270452/    2018
# 283  http://www.imdb.com/title/tt2473110/
# 284  http://www.imdb.com/title/tt1837687/
# 285  http://www.imdb.com/title/tt6069264/  2017/I
# 286  http://www.imdb.com/title/tt4381236/    2016
# 287  http://www.imdb.com/title/tt3349380/    2015
# 288  http://www.imdb.com/title/tt2443822/  2015/I
# 289  http://www.imdb.com/title/tt3455740/    2014
# 290  http://www.imdb.com/title/tt2409818/    2014
# 291  http://www.imdb.com/title/tt2326554/    2014
# 292  http://www.imdb.com/title/tt2490326/    2014
# 293  http://www.imdb.com/title/tt2660332/    2013
# 294  http://www.imdb.com/title/tt2076372/    2012
#
# [151 rows x 8 columns]

# %%
tina1 = requests.get('http://www.theimdbapi.org/api/person?person_id=nm0001499').json()
tina1

# %%
tina2 = requests.get('http://www.theimdbapi.org/api/find/person?name=Mindy%20Kaling').json()
tina2

# %%
tina3 = [tina1]
tina3

# %%
# TEST

moviedb_imdb_id = "https://api.themoviedb.org/3/movie/"
moviedb_key = '21acf1b7274aa72fe97cd9acc7eb382a'

test_ids = ['tt0120737', # Lord of the Rings
            'tt0133093', # The Matrix
            'tt1935089'] # Blind

test_moviedb_ids = {}
for t in test_ids:
    result = moviedb_imdb_id + t + "?" + urllib.parse.urlencode({'api_key': moviedb_key}) + "&external_source=imdb_id"
    
    imdb = t
    moviedb = result
    test_moviedb_ids[imdb] = moviedb

test_moviedb_ids

# %%
# TEST

test1_ids = {}
for t, m in test_moviedb_ids.items():
    test1_json = requests.get(m).json()
    
    #print(test1_json)
    
    ids = test1_json['id']
    titles = test1_json['title']
    test1_ids[ids] = titles
    #test1_ids.append(test1_ids)
    
test1_ids

# %%
# TEST

test_credits = {'moviedb_id': '0000',
               'title': 'test',
               'name': 'test',
               'role': 'test'}
    
df_credits_test = pd.DataFrame(test_credits, index = [0])

df_credits_test

# %%
# TEST

df_credits_test
for i, t in test1_ids.items():
    credits_url = moviedb_imdb_id + str(i) + "/credits?" + urllib.parse.urlencode({'api_key': moviedb_key})
    credits_json = requests.get(credits_url).json()
    
    try:
        cast = pd.DataFrame(credits_json['cast']).assign(moviedb_id = lambda x: i, title = lambda x: t, role = lambda x: 'Actor')
        df_credits_test = df_credits_test.append(cast, ignore_index = True)
        crew = pd.DataFrame(credits_json['crew']).assign(moviedb_id = lambda x: i, title = lambda x: t)
        crew = crew.rename(columns = {'job': 'role'})
        df_credits_test = df_credits_test.append(crew, ignore_index = True)
    except KeyError:
        pass

df_credits_test.head()

# %%
# TEST

df_credits_test = df_credits_test.drop(['cast_id', 'character', 'credit_id', 'department', 'id', 'order', 'profile_path'], axis = 1)

df_credits_test.head()

# %%
# Movie DB call with IMDb ID 
# https://api.themoviedb.org/3/find/tt1935089?api_key=21acf1b7274aa72fe97cd9acc7eb382a&external_source=imdb_id

# Movie DB call with Movie DB ID
#https://api.themoviedb.org/3/movie/364733?api_key=21acf1b7274aa72fe97cd9acc7eb382a

# Movie DB call for cast
# https://api.themoviedb.org/3/movie/364733/credits?api_key=21acf1b7274aa72fe97cd9acc7eb382a

# %%
# Test

dict = {'tt1935089': 'http://www.theimdbapi.org/api/movie?movie_id=tt1935089', 
        'tt4975302': 'http://www.theimdbapi.org/api/movie?movie_id=tt4975302', 
        'tt2452352': 'http://www.theimdbapi.org/api/movie?movie_id=tt2452352'}

test_hold = {'imdb_id': 'tt0000000',
               'title': 'test',
               'url': 'http://www.test.com/',
               'year': '2017',
               'name': 'test',
               'role': 'test'}
    
df_test = pd.DataFrame(test_hold, index = [0])

df_test

# %%
for a, b in dict.items():
    test_json = requests.get(b).json()
    print(test_json['title'])
    print(test_json['url']['url'])
    print(test_json['director'])
    print(test_json['writers'])
    print(test_json['stars'])

# df_test.info()


#try:
#    df_temp = pd.DataFrame(abuser_json[0]['filmography'][r]).assign(name = lambda x: abuser , role = lambda x: r) 
#    df_abusers = df_abusers.append(df_temp, ignore_index = True)
#except KeyError:
#    pass

# %%
# Loop through `person_moviedb_urls` in the MovieDB API to access corresponding IMDB IDs

person_imdb_ids = {}
for i, u in person_moviedb_urls.items():
    person_json = requests.get(u).json
    
    # Create `person_imdb_ids` dictionary
    
    try:
        ids = i
        imdb_ids = person_json['imdb_id']
        person_imdb_ids[ids] = imdb_ids
    except KeyError:
        pass

# debugging: person_imdb_ids
